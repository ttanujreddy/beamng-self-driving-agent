# %%
# !pip install beamngpy
# Out:
# ...
#    ---------------------------------------- 0.0/753.4 kB ? eta -:--:--
#    ---------------------------------------- 753.4/753.4 kB 15.5 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [seaborn]
#    ------------- -------------------------- 1/3 [seaborn]
#    ------------- -------------------------- 1/3 [seaborn]
#    ------------- -------------------------- 1/3 [seaborn]
#    -------------------------- ------------- 2/3 [beamngpy]
#    -------------------------- ------------- 2/3 [beamngpy]
#    -------------------------- ------------- 2/3 [beamngpy]
#    -------------------------- ------------- 2/3 [beamngpy]
#    -------------------------- ------------- 2/3 [beamngpy]
#    ---------------------------------------- 3/3 [beamngpy]
#
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\Brendel\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
